# %% [markdown]
# # Gemini News Feature Playground
#
# Interactively load historical news articles, call the Gemini 2.5 Flash model with the structured prompt, and inspect the extracted features alongside the rolling context summary.

# %% [markdown]
# ## Prerequisites
#
# - Install dependencies: `pip install google-generativeai pandas ipywidgets python-dateutil`.
# - Export your Gemini API key before running: `setx GOOGLE_API_KEY "<your key>"` (PowerShell) then restart the notebook kernel.
# - Ensure the cleaned news JSON files exist under `data_clean/bronze/news/historical_5year`.
#
# All requests in this notebook run sequentially to respect rate limits.

# %%
# Standard library imports
import json,sys
from pathlib import Path
from datetime import datetime, date, time, timezone

# Third-party imports
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, Markdown

sys.path.append(r"c:\\Users\\user\\Desktop\\kz code\\fx-ml-pipeline")

from src_clean.data_pipelines.silver.LLM_news_feature_pipelines import (
    NewsLLMFeaturePipeline,
    combine_article_text,
)

# %%
from pathlib import Path

import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyCIh_EGlbK5LI0BpcOpzRkKFka-IgOtdH0"

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent



try:
    from dotenv import load_dotenv
    load_dotenv()
except Exception:
    pass

import os
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')
if not GOOGLE_API_KEY:
    display(Markdown('?? **Warning**: GOOGLE_API_KEY is not set. Set it before running the LLM calls.'))

if not INPUT_DIR.exists():
    raise FileNotFoundError(f'Expected directory not found: {INPUT_DIR}')

DEFAULT_START = date(2023, 6, 1)
DEFAULT_END = date(2023, 6, 7)

# %%
PROJECT_ROOT
# Out:
# WindowsPath('C:/Users/user/Desktop/kz code/fx-ml-pipeline')

# %%
# Widgets to select the date window and maximum number of articles
start_picker = widgets.DatePicker(description='Start Date', value=DEFAULT_START)
end_picker = widgets.DatePicker(description='End Date', value=DEFAULT_END)
max_articles_slider = widgets.IntSlider(description='Max articles', min=1, max=20, value=5)
model_text = widgets.Text(description='Gemini model', value='gemini-2.5-flash-lite')

widgets.VBox([
    widgets.HTML('<b>Select date window and settings</b>'),
    start_picker,
    end_picker,
    max_articles_slider,
    model_text,
])
# Out:
# VBox(children=(HTML(value='<b>Select date window and settings</b>'), DatePicker(value=datetime.date(2023, 6, 1…

# %%
from typing import List, Dict, Any
from datetime import datetime
from src_clean.data_pipelines.silver.LLM_news_manifest import filter_manifest

def load_articles_between(input_dir: Path, start: date, end: date, limit: int) -> List[Dict[str, Any]]:
    # Load and filter articles by published_at timestamp.
    if start is None or end is None:
        raise ValueError('Please select both start and end dates.')

    start_dt = datetime.combine(start, time.min, tzinfo=timezone.utc)
    end_dt = datetime.combine(end, time.max, tzinfo=timezone.utc)

    manifest = Path("../data_clean/silver/news/news_manifest_cleaned_20251022_122221.parquet")
    df = filter_manifest(
        manifest,
        start=start_dt,
        end=end_dt,
        limit=None,
    )

    articles = []
    for path_str in df.file_path:
        path = PROJECT_ROOT / Path(path_str)
        with path.open("r", encoding="utf-8") as f:
            article = json.load(f)
        articles.append(article)

    df = pd.DataFrame(articles)

    # remove duplicates, keep earliest published dates
    before = len(df)
    df = df.sort_values("published_at", ascending=True)
    df = df.drop_duplicates(subset=["headline"], keep="first")
    after = len(df)
    dropped = before - after
    if dropped:
        display(Markdown(f"⚠️ **Warning**: dropped {dropped} duplicate row(s)."))

    before = len(df)
    df = df[df['body'].str.len()>0]
    after = len(df)
    dropped = before - after
    if dropped:
        display(Markdown(f"⚠️ **Warning**: dropped {dropped} row(s) that has empty body."))


    return df

# %%
# Load articles for the selected window
selected_articles = load_articles_between(
    INPUT_DIR,
    start_picker.value or DEFAULT_START,
    end_picker.value or DEFAULT_END,
    max_articles_slider.value,
)

display(selected_articles)
selected_articles.to_clipboard()
# Out:
#                           article_id  \
# 0   36052f0b0998bc21fbecd60e7f7395ae
# 1   89cdabc5d9bdf783236c1997f1cf560d
# 2   f90a6b0903fb43b21eed0a4bb42cca44
# 3   d16913739539125c51ccfd15ff016fe2
# 4   4ae55e66bb63e912d78fb6c7e0cf639e
# 5   379faa5b51ec03f81fe6a6083480c766
# 6   47733be43dc74fe11fd108836400ca2a
# 7   c1aec02727f21b5f99e40f122231903e
# 8   f7cd81922e35f99e1e6744d0a2f1c55f
# 9   13184fb767580c0b1bc45f7b37629ed3
# 10  222d13d931a5e1d43334517af78d68f2
# 11  c2e7758edc525ce1096656335f281ac8
# 12  6d4a2ca35c95d9207b0d9a6006b09ffc
# 14  86ed4df5f456170f4b5c1f44423edf40
# 13  d369b20b088291e3606544742ff872d7
# 15  5a5be8e7f355cbed026e4ce6ab60f446
# 16  89321f2a0aec304fb55f861b7344c2ea
# 17  157b2c9b5f61269156f07c6307be301f
# 18  e60445a51883908443c6201b08bb618e
# 19  e20bcf11f224a986ee97ee780061988b
# 20  90dc045ea07246dd8668a85499080b8c
# 21  40b2b735a5fd48eecad4c56bd4293834
# 22  f56a9486e0ccd9781dca00779ff35152
# 23  14a33dbfe749252d8f4f58dade657b73
# 24  2e962fb537826e5ebfdf4b3683c6bf01
# 25  aef5b3a7d1c0d80c1df9d5705e5e1ffa
# 26  9dc1b2874fb13fe4152e07f7a5b90576
# 27  fd0c8bd977410eb6fe85e50c369a2b74
# 28  c4f6b8c7db8ea31e9750b6cead0e62c2
# 29  fd71057b7c1a4dff0c8d897fe7744ee6
# 30  7b8d82448ce7bef901624efd14167ea0
# 31  b518c285e61adf4c1869ec8a50079198
# 32  377114781be4dbec87ecbc42f373af3b
# 33  3dee5528729081f30ece62c89921ac24
# 34  6b4e0e8ad9b2c072df43f7edd8d04029
# 35  28b79150644819282a787af521aa720d
# 36  1042351cff45ce14b1babcab75f7b40e
# 37  ef61e5c393aba5437d64846707a3e8d3
# 38  72649598447e8d46c86b150fd95737b6
# 39  e291d78e7c853a61d5bb53a8649a74fc
# 40  3ec6c8329d26860456d9ce9402a9effe
# 41  32ac17f69c3b05d7f70a6da9424255f9
# 42  e3e4cffb56c622df9bfa32e2bc7859aa
# 43  7cd4a3c4abe707832f623a3dcf66b646
# 44  1942b328d6b3e7cbc7bcbc1036c3d6a4
# 45  b3065618b1aba2a36cfd6622c1be5d8a
# 46  a49b756fac83879a6b2b662f230a18e9
# 47  9215114be7895aa1c29e7e752dc16eb7
# 48  ed81acb8f25309a7648966b8d501d1f8
# 29  2025-10-20T11:16:58.859547+00:00            True         gdelt_api
# 30  2025-10-20T11:16:58.859547+00:00            True         gdelt_api
# 31  2025-10-20T11:16:58.865508+00:00            True         gdelt_api
# 32  2025-10-20T11:16:58.859547+00:00            True         gdelt_api
# 33  2025-10-20T11:16:58.859547+00:00            True         gdelt_api
# 34  2025-10-20T11:16:58.859547+00:00            True         gdelt_api
# 35  2025-10-20T11:16:58.865508+00:00            True         gdelt_api
# 36  2025-10-20T11:16:58.859547+00:00            True         gdelt_api
# 37  2025-10-20T11:18:13.494973+00:00            True         gdelt_api
# 38  2025-10-20T11:18:13.494973+00:00            True         gdelt_api
# 39  2025-10-20T11:18:13.500523+00:00            True         gdelt_api
# 40  2025-10-20T11:18:13.496983+00:00            True         gdelt_api
# 41  2025-10-20T11:18:13.496983+00:00            True         gdelt_api
# 42  2025-10-20T11:18:13.496983+00:00            True         gdelt_api
# 43  2025-10-20T11:18:13.496983+00:00            True         gdelt_api
# 44  2025-10-20T11:18:13.500523+00:00            True         gdelt_api
# 45  2025-10-20T11:18:13.496983+00:00            True         gdelt_api
# 46  2025-10-20T11:18:13.498990+00:00            True         gdelt_api
# 47  2025-10-20T11:18:13.496983+00:00            True         gdelt_api
# 48  2025-10-20T11:19:08.540135+00:00            True         gdelt_api
# 49  2025-10-20T11:19:08.540135+00:00            True         gdelt_api
# 50  2025-10-20T11:19:08.538127+00:00            True         gdelt_api
# 51  2025-10-20T11:19:08.540135+00:00            True         gdelt_api
# 52  2025-10-20T11:19:08.538127+00:00            True         gdelt_api
# 53  2025-10-20T11:19:08.540135+00:00            True         gdelt_api
# 54  2025-10-20T11:19:08.540135+00:00            True         gdelt_api
#
#       language  content_fetched
# 0       French             True
# 1   Indonesian             True
# 2   Indonesian             True
# 3      English             True
# 4      English             True
# 5      English             True
# 6      English             True
# 7      English             True
# 8   Indonesian             True
# 9   Indonesian             True
# 10  Indonesian             True
# 11  Vietnamese             True
# 12     English             True
# 14     English             True
# 13     English             True
# 15     English             True
# 16  Indonesian             True
# 17  Indonesian             True
# 18     English             True
# 19     English             True
# 20     English             True
# 21     English             True
# 22     Italian             True
# 23     English             True
# 24  Indonesian             True
# 25      Korean             True
# 26     English             True
# 27     English             True
# 28     English             True
# 29     English             True
# 30     English             True
# 31     English             True
# 32     English             True
# 33     English             True
# 34     English             True
# 35     English             True
# 36     English             True
# 37  Indonesian             True
# 38  Indonesian             True
# 39    Croatian             True
# 40     English             True
# 41     English             True
# 42     English             True
# 43     English             True
# 44      French             True
# 45      French             True
# 46     Chinese             True
# 47  Indonesian             True
# 48  Indonesian             True
# 49     English             True
# 50     English             True
# 51     Italian             True
# 52     English             True
# 53     English             True
# 54     English             True

# %%
# Sequentially call Gemini with rolling context
from src_clean.data_pipelines.silver.LLM_news_manifest import filter_manifest
from src_clean.data_pipelines.silver.clean_manifest import clean_manifest_df

MANIFEST_PATH = PROJECT_ROOT / 'data_clean/silver/news/news_manifest_cleaned_20251022_122221.parquet'

def run_sequential_llm_calls(start: date, end: date, limit: int, model_name: str = 'gemini-2.5-flash'):
    manifest_df = filter_manifest(
        MANIFEST_PATH,
        start=datetime.combine(start, time.min, tzinfo=timezone.utc),
        end=datetime.combine(end, time.max, tzinfo=timezone.utc),
        limit=limit,
    )

    if manifest_df.empty:
        return []

    manifest_df = clean_manifest_df(manifest_df)

    pipeline = NewsLLMFeaturePipeline(
        manifest_path=MANIFEST_PATH,
        output_path=PROJECT_ROOT / 'data_clean/silver/news/gemini_feature_test.parquet',
        model=model_name or 'gemini-2.5-flash',
        context_history='No prior context provided.',
    )

    results = []
    context_summary = pipeline.context_history

    for idx, row in manifest_df.iterrows():
        pipeline.context_history = context_summary
        feature_row, article = pipeline._analyze_article(row)
        context_summary = feature_row.get('context_history_summary') or context_summary

        feature_row.update(
            {
                'sequence_idx': idx + 1,
                'article_id': row.get('article_id') or article.get('article_id'),
                'published_at': row.get('published_at') or article.get('published_at'),
                'headline': row.get('headline') or article.get('headline'),
            }
        )
        results.append(feature_row)
    return results

# %%
import json
from src_clean.data_pipelines.silver.LLM_news_feature_pipelines import NewsFeatureSchema
from src_clean.data_pipelines.silver import LLM_news_feature_pipelines as nf
import importlib

# Reload if you've just edited the module
importlib.reload(nf)

# 1) Raw Pydantic schema
raw_schema = NewsFeatureSchema.model_json_schema()
print(json.dumps(raw_schema, indent=2))

# 2) Schema after stripping unsupported fields (the one Gemini sees)
pipeline = nf.NewsLLMFeaturePipeline(
    manifest_path=PROJECT_ROOT / "data_clean/bronze/news/historical_5year",
    output_path=PROJECT_ROOT / "tmp.parquet",
    provider="gemini",
)
print(json.dumps(pipeline.response_schema, indent=2))
# Out:
# {
#   "properties": {
#     "sentiment_score": {
#       "maximum": 1.0,
#       "minimum": -1.0,
#       "title": "Sentiment Score",
#       "type": "number"
#     },
#     "subjectivity": {
#       "maximum": 1.0,
#       "minimum": 0.0,
#       "title": "Subjectivity",
#       "type": "number"
#     },
#     "volatility_flag": {
#       "title": "Volatility Flag",
#       "type": "boolean"
#     },
#     "uncertainty_score": {
#       "maximum": 1.0,
#       "minimum": 0.0,
#       "title": "Uncertainty Score",
#       "type": "number"
#     },
#     "sentiment_score_vs_expectation": {
#       "maximum": 1.0,
#       "minimum": -1.0,
#       "title": "Sentiment Score Vs Expectation",
#       "type": "number"
#     },
#     "confidence_in_trend": {
#       "maximum": 1.0,
#       "minimum": 0.0,
#       "title": "Confidence In Trend",
#       "type": "number"
#     },
#     "market_reaction_flag": {
#       "title": "Market Reaction Flag",
#       "type": "boolean"
#     },
#     "emotion_keywords": {
#       "items": {
#         "type": "string"
#       },
#       "title": "Emotion Keywords",
#       "type": "array"
#     },
#     "named_entities": {
#       "items": {
#         "type": "string"
#       },
#       "title": "Named Entities",
#       "type": "array"
#     },
#     "entity_sentiment": {
#       "additionalProperties": {
#         "type": "number"
#       },
#       "title": "Entity Sentiment",
#       "type": "object"
#     },
#     "is_macro_related": {
#       "maximum": 10.0,
#       "minimum": 0.0,
#       "title": "Is Macro Related",
#       "type": "number"
#     },
#     "relevance_to_stock": {
#       "maximum": 1.0,
#       "minimum": 0.0,
#       "title": "Relevance To Stock",
#       "type": "number"
#     },
#     "industry_sector": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "title": "Industry Sector"
#     },
#     "policy_impact_flag": {
#       "title": "Policy Impact Flag",
#       "type": "boolean"
#     },
#     "geography_mentions": {
#       "items": {
#         "type": "string"
#       },
#       "title": "Geography Mentions",
#       "type": "array"
#     },
#     "time_horizon": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "title": "Time Horizon"
#     },
#     "data_dependency_flag": {
#       "title": "Data Dependency Flag",
#       "type": "boolean"
#     },
#     "event_type": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "title": "Event Type"
#     },
#     "event_impact_level": {
#       "maximum": 1.0,
#       "minimum": 0.0,
#       "title": "Event Impact Level",
#       "type": "number"
#     },
#     "volatility_trigger_keywords": {
#       "items": {
#         "type": "string"
#       },
#       "title": "Volatility Trigger Keywords",
#       "type": "array"
#     },
#     "sentiment_trend": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "title": "Sentiment Trend"
#     },
#     "surprise_indicator": {
#       "maximum": 1.0,
#       "minimum": -1.0,
#       "title": "Surprise Indicator",
#       "type": "number"
#     },
#     "liquidity_impact_flag": {
#       "title": "Liquidity Impact Flag",
#       "type": "boolean"
#     },
#     "safe_haven_mention_flag": {
#       "title": "Safe Haven Mention Flag",
#       "type": "boolean"
#     },
#     "risk_appetite_score": {
#       "maximum": 1.0,
#       "minimum": 0.0,
#       "title": "Risk Appetite Score",
#       "type": "number"
#     },
#     "context_history_summary": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "title": "Context History Summary"
#     },
#     "short_summary": {
#       "title": "Short Summary",
#       "type": "string"
#     },
#     "key_new_information": {
#       "items": {
#         "type": "string"
#       },
#       "title": "Key New Information",
#       "type": "array"
#     },
#     "overall_market_sentiment": {
#       "anyOf": [
#         {
#           "type": "string"
#         },
#         {
#           "type": "null"
#         }
#       ],
#       "title": "Overall Market Sentiment"
#     }
#   },
#   "required": [
#     "sentiment_score",
#     "subjectivity",
#     "volatility_flag",
#     "uncertainty_score",
#     "sentiment_score_vs_expectation",
#     "confidence_in_trend",
#     "market_reaction_flag",
#     "emotion_keywords",
#     "named_entities",
#     "entity_sentiment",
#     "is_macro_related",
#     "relevance_to_stock",
#     "industry_sector",
#     "policy_impact_flag",
#     "geography_mentions",
#     "time_horizon",
#     "data_dependency_flag",
#     "event_type",
#     "event_impact_level",
#     "volatility_trigger_keywords",
#     "sentiment_trend",
#     "surprise_indicator",
#     "liquidity_impact_flag",
#     "safe_haven_mention_flag",
#     "risk_appetite_score",
#     "context_history_summary",
#     "short_summary",
#     "key_new_information",
#     "overall_market_sentiment"
#   ],
#   "title": "NewsFeatureSchema",
#   "type": "object"
# }
# {
#   "properties": {
#     "sentiment_score": {
#       "type": "number"
#     },
#     "subjectivity": {
#       "type": "number"
#     },
#     "volatility_flag": {
#       "type": "boolean"
#     },
#     "uncertainty_score": {
#       "type": "number"
#     },
#     "sentiment_score_vs_expectation": {
#       "type": "number"
#     },
#     "confidence_in_trend": {
#       "type": "number"
#     },
#     "market_reaction_flag": {
#       "type": "boolean"
#     },
#     "emotion_keywords": {
#       "items": {
#         "type": "string"
#       },
#       "type": "array"
#     },
#     "named_entities": {
#       "items": {
#         "type": "string"
#       },
#       "type": "array"
#     },
#     "entity_sentiment": {
#       "type": "object"
#     },
#     "is_macro_related": {
#       "type": "number"
#     },
#     "relevance_to_stock": {
#       "type": "number"
#     },
#     "industry_sector": {},
#     "policy_impact_flag": {
#       "type": "boolean"
#     },
#     "geography_mentions": {
#       "items": {
#         "type": "string"
#       },
#       "type": "array"
#     },
#     "time_horizon": {},
#     "data_dependency_flag": {
#       "type": "boolean"
#     },
#     "event_type": {},
#     "event_impact_level": {
#       "type": "number"
#     },
#     "volatility_trigger_keywords": {
#       "items": {
#         "type": "string"
#       },
#       "type": "array"
#     },
#     "sentiment_trend": {},
#     "surprise_indicator": {
#       "type": "number"
#     },
#     "liquidity_impact_flag": {
#       "type": "boolean"
#     },
#     "safe_haven_mention_flag": {
#       "type": "boolean"
#     },
#     "risk_appetite_score": {
#       "type": "number"
#     },
#     "context_history_summary": {},
#     "short_summary": {
#       "type": "string"
#     },
#     "key_new_information": {
#       "items": {
#         "type": "string"
#       },
#       "type": "array"
#     },
#     "overall_market_sentiment": {}
#   },
#   "required": [
#     "sentiment_score",
#     "subjectivity",
#     "volatility_flag",
#     "uncertainty_score",
#     "sentiment_score_vs_expectation",
#     "confidence_in_trend",
#     "market_reaction_flag",
#     "emotion_keywords",
#     "named_entities",
#     "entity_sentiment",
#     "is_macro_related",
#     "relevance_to_stock",
#     "industry_sector",
#     "policy_impact_flag",
#     "geography_mentions",
#     "time_horizon",
#     "data_dependency_flag",
#     "event_type",
#     "event_impact_level",
#     "volatility_trigger_keywords",
#     "sentiment_trend",
#     "surprise_indicator",
#     "liquidity_impact_flag",
#     "safe_haven_mention_flag",
#     "risk_appetite_score",
#     "context_history_summary",
#     "short_summary",
#     "key_new_information",
#     "overall_market_sentiment"
#   ],
#   "type": "object"
# }

# %%
# Run the sequential analysis
sequential_results = run_sequential_llm_calls(
    start=start_picker.value or DEFAULT_START,
    end=end_picker.value or DEFAULT_END,
    limit=max_articles_slider.value,
    model_name=model_text.value,
)

if sequential_results:
    display(Markdown('### LLM Output'))
    display(pd.json_normalize(sequential_results))
    display(Markdown('### Final Context Summary'))
    display(Markdown(sequential_results[-1].get('context_history_summary', '(missing)')))
else:
    display(Markdown('⚠️ No articles processed.'))

# %%
import importlib
import pandas as pd
import src_clean.data_pipelines.silver.LLM_news_feature_pipelines as nf

# Reload module to pick up recent edits
importlib.reload(nf)

INPUT_MANIFEST = PROJECT_ROOT / "data_clean/gold/news/news_with_features.parquet"
pipeline = nf.NewsLLMFeaturePipeline(
    manifest_path=INPUT_MANIFEST,
    output_path=PROJECT_ROOT / "data_clean/silver/news/gemini_feature_test.parquet",
    model= "gemini-2.0-flash-lite",
    context_history="No prior context provided.",
)

manifest_df = pipeline._load_manifest()
if manifest_df.empty:
    raise ValueError("Manifest is empty. Run the join pipeline first.")

debug_row = manifest_df.iloc[5]

try:
    result, article, prompt = pipeline._analyze_article(debug_row)
    print("LLM output (dict):")
    print(result)
except Exception as exc:
    print("Validation failure:", exc)

# Load the model
import google.generativeai as genai
model = genai.GenerativeModel("gemini-2.0-flash-lite")


# Count tokens
count = model.count_tokens(prompt)
print("Input Token count:", count.total_tokens)
# Count tokens
count = model.count_tokens(str(result))
print("Output Token count:", count.total_tokens)
# Out:
# LLM output (dict):
# {'sentiment_score': 0.3, 'sentiment_magnitude': 0.6, 'subjectivity': 0.2, 'uncertainty_score': 0.1, 'confidence_in_trend': 0.6, 'sentiment_score_vs_expectation': 0.1, 'sentiment_trend': 'Improving', 'sentiment_trend_strength': 0.5, 'surprise_indicator': 0.0, 'emotion_intensity_score': 0.4, 'volatility_flag': False, 'market_reaction_flag': True, 'reaction_magnitude_score': 0.5, 'volatility_pressure_score': 0.3, 'emotion_keywords': ['positive'], 'predicted_price_impact_direction': 1.0, 'predicted_price_impact_probability': 0.6, 'predicted_price_impact_magnitude': 0.3, 'impact_duration_category': 'intraday', 'impact_duration_score': 0.3, 'catalyst_type': 'earnings', 'catalyst_strength_score': 0.7, 'named_entities': ['S&P 500', 'Nasdaq', 'Netflix'], 'entity_sentiment': {'Netflix': -0.5}, 'is_macro_related': 3.0, 'macro_sentiment_score': 0.2, 'relevance_to_stock': 0.7, 'industry_sector': None, 'sector_sentiment_score': 0.3, 'cross_sector_correlation_score': 0.3, 'policy_impact_flag': False, 'policy_bias_score': 0.0, 'data_dependency_flag': False, 'data_tone_score': 0.3, 'geography_mentions': ['US', 'Europe'], 'geopolitical_tension_score': 0.0, 'cross_asset_impact_score': 0.1, 'relative_to_historical_sentiment': 0.2, 'deviation_from_historical_volatility': 0.2, 'narrative_continuity_score': 0.8, 'cumulative_context_bias_score': 0.1, 'historical_similarity_examples': [], 'recency_alignment_score': 0.7, 'event_type': 'earnings report', 'event_impact_level': 0.5, 'event_novelty_score': 0.2, 'volatility_trigger_keywords': [], 'liquidity_impact_flag': False, 'liquidity_stress_score': 0.0, 'safe_haven_mention_flag': False, 'risk_appetite_score': 0.6, 'time_horizon': 'intraday', 'time_horizon_numeric': 0.1, 'context_history_summary': 'The S&P 500 opened higher, with the Nasdaq up 0.7%. European markets are down.', 'short_summary': 'US markets opened higher, with the S&P 500 up and the Nasdaq up. European markets are down.', 'key_new_information': ['S&P 500 up 0.2%', 'Nasdaq up 0.7%', 'European markets down'], 'overall_market_sentiment': 'Bullish', 'overall_market_sentiment_score': 0.4, 'model_confidence_score': 0.8, 'language_detected': 'Finnish'}
# Input Token count: 5260
# Output Token count: 765

# %%
result
# Out:
# {'sentiment_score': 0.4,
#  'sentiment_magnitude': 0.4,
#  'subjectivity': 0.3,
#  'uncertainty_score': 0.2,
#  'confidence_in_trend': 0.6,
#  'sentiment_score_vs_expectation': 0.3,
#  'sentiment_trend': 'improving',
#  'sentiment_trend_strength': 0.4,
#  'surprise_indicator': 0.1,
#  'emotion_intensity_score': 0.3,
#  'volatility_flag': False,
#  'market_reaction_flag': True,
#  'reaction_magnitude_score': 0.2,
#  'volatility_pressure_score': 0.1,
#  'emotion_keywords': ['erinomaisesti', 'pettymys'],
#  'predicted_price_impact_direction': 0.3,
#  'predicted_price_impact_probability': 0.6,
#  'predicted_price_impact_magnitude': 0.4,
#  'impact_duration_category': 'intraday',
#  'impact_duration_score': 0.3,
#  'catalyst_type': 'earnings',
#  'catalyst_strength_score': 0.4,
#  'named_entities': ['Netflix', 'S&P 500', 'Nasdaq'],
#  'entity_sentiment': {'Netflix': -0.5},
#  'is_macro_related': 0.5,
#  'macro_sentiment_score': 0.0,
#  'relevance_to_stock': 0.8,
#  'industry_sector': 'technology',
#  'sector_sentiment_score': 0.4,
#  'cross_sector_correlation_score': 0.2,
#  'policy_impact_flag': False,
#  'policy_bias_score': 0.0,
#  'data_dependency_flag': True,
#  'data_tone_score': 0.7,
#  'geography_mentions': ['Yhdysvaltain', 'Amerikan', 'Euroopan'],
#  'geopolitical_tension_score': 0.0,
#  'cross_asset_impact_score': 0.0,
#  'relative_to_historical_sentiment': 0.2,
#  'deviation_from_historical_volatility': 0.2,
#  'narrative_continuity_score': 0.5,
#  'cumulative_context_bias_score': 0.3,
#  'historical_similarity_examples': [],
#  'recency_alignment_score': 0.6,
#  'event_type': 'earnings report',
#  'event_impact_level': 0.4,
#  'event_novelty_score': 0.3,
#  'volatility_trigger_keywords': [],
#  'liquidity_impact_flag': False,
#  'liquidity_stress_score': 0.0,
#  'safe_haven_mention_flag': False,
#  'risk_appetite_score': 0.5,
#  'time_horizon': 'intraday',
#  'time_horizon_numeric': 0.1,
#  'context_history_summary': 'The article indicates a positive opening for US stock markets, with the S&P 500 up 0.2% and Nasdaq up 0.7% after half an hour of trading. This is attributed to a strong start to the US earnings season, with most companies exceeding analyst expectations, despite a disappointing result from Netflix. European markets, however, showed a weaker sentiment with major indices down around 1%.',
#  'short_summary': "US stock markets opened higher with the S&P 500 and Nasdaq gaining due to a strong start to the earnings season, despite Netflix's disappointing results. European markets, however, trended downwards.",
#  'key_new_information': ['US stock markets opened higher.',
#   'S&P 500 and Nasdaq showed gains.',
#   'Most earnings reports exceeded expectations.',
#   'Netflix earnings were a disappointment.',
#   'European markets were down.'],
#  'overall_market_sentiment': 'Bullish',
#  'overall_market_sentiment_score': 0.4,
#  'model_confidence_score': 0.7,
#  'language_detected': 'Finnish'}

# %%
df = pd.read_parquet('../data_clean/gold/news/LLM_news.parquet')
df["published_at"] = pd.to_datetime(df["published_at"]).dt.tz_localize(None)
df.to_excel("output.xlsx", index=False)

# %%
df
# Out:
#       sentiment_score  sentiment_magnitude  subjectivity  uncertainty_score  \
# 0                -0.5                  0.5           0.4                0.4
# 1                -0.6                  0.7           0.8                0.6
# 2                 0.5                  0.6           0.8                0.7
# 3                 0.2                  0.5           0.7                0.6
# 4                 0.1                  0.4           0.5                0.6
# ...               ...                  ...           ...                ...
# 1835              NaN                  NaN           NaN                NaN
# 1836              NaN                  NaN           NaN                NaN
# 1837              NaN                  NaN           NaN                NaN
# 1838              NaN                  NaN           NaN                NaN
# 1839              NaN                  NaN           NaN                NaN
#
#       confidence_in_trend  sentiment_score_vs_expectation sentiment_trend  \
# 0                     0.3                            -0.6       worsening
# 1                     0.3                            -0.7       worsening
# 2                     0.7                             0.4          stable
# 3                     0.6                             0.1          stable
# 4                     0.6                             0.1       improving
# ...                   ...                             ...             ...
# 1835                  NaN                             NaN            None
# 1836                  NaN                             NaN            None
# 1837                  NaN                             NaN            None
# 1838                  NaN                             NaN            None
# 1839                  NaN                             NaN            None
#
#       sentiment_trend_strength  surprise_indicator  emotion_intensity_score  \
# 0                          0.4                -0.5                      0.3
# 1                          0.7                -0.6                      0.7
# 2                          0.3                 0.1                      0.5
# 3                          0.2                 0.1                      0.5
# 4                          0.4                 0.1                      0.4
# ...                        ...                 ...                      ...
# 1835                       NaN                 NaN                      NaN
# 1836                       NaN                 NaN                      NaN
# 1837                       NaN                 NaN                      NaN
# 1838                       NaN                 NaN                      NaN
# 1839                       NaN                 NaN                      NaN
#
#       ...                                key_new_information  \
# 0     ...  [Chinese stock market reversed early gains and...
# 1     ...  [China's Q3 GDP grew by 4.9%., China's economy...
# 2     ...  [Stock market crashes are normal and unprevent...
# 3     ...  [S&P 500 has recorded 12 of its 15 largest sin...
# 4     ...  [Wall Street menguat di awal perdagangan Rabu....
# ...   ...                                                ...
# 1835  ...                                               None
# 1836  ...                                               None
# 1837  ...                                               None
# 1838  ...                                               None
# 1839  ...                                               None
#
#      overall_market_sentiment  overall_market_sentiment_score  \
# 0                     Bearish                            -0.4
# 1                     Bearish                            -0.6
# 2                     Neutral                             0.1
# 3                     Neutral                             0.1
# 4                     Neutral                             0.1
# ...                       ...                             ...
# 1835                     None                             NaN
# 1836                     None                             NaN
# 1837                     None                             NaN
# 1838                     None                             NaN
# 1839                     None                             NaN
#
#       model_confidence_score language_detected  \
# 0                       0.50           Chinese
# 1                       0.70           Chinese
# 2                       0.85           English
# 3                       0.80           English
# 4                       0.80                id
# ...                      ...               ...
# 1835                     NaN              None
# 1836                     NaN              None
# 1837                     NaN              None
# 1838                     NaN              None
# 1839                     NaN              None
#
#                             article_id              published_at  \
# 0     fe5201b8430c30bb6eb9513fc9227a19 2020-10-19 09:30:00+00:00
# 1     ff434099c7b77b6ab6395b9e95560437 2020-10-19 11:00:00+00:00
# 2     ba853d93b28568870abfea3b9959429e 2020-10-19 11:15:00+00:00
# 3     7027368bd2cc529ea3b7ef5b0f13a0f4 2020-10-21 12:45:00+00:00
# 4     95b030051539adae2a486ec59b50bbcf 2020-10-21 15:00:00+00:00
# ...                                ...                       ...
# 1835  c1f2f9e80b00bbe39d931158bdb0f696 2021-10-08 00:00:00+00:00
# 1836  b219bf59716ff57d361275b1d5b57573 2021-10-08 00:15:00+00:00
# 1837  5bacfa05b7eb90e144daa7fac561d361 2021-10-09 00:30:00+00:00
# 1838  d94379ed9ce513cf095222084863dcd0 2021-10-09 00:30:00+00:00
# 1839  134e64d04f695279662cfe244cd77ae8 2021-10-09 03:45:00+00:00
#
#                              source  \
# 0              gdelt_cn.reuters.com
# 1          gdelt_blog.eastmoney.com
# 2                    gdelt_fool.com
# 3                    gdelt_fool.com
# 4      gdelt_investasi.kontan.co.id
# ...                             ...
# 1835  gdelt_investmentwatchblog.com
# 1836      gdelt_economy.okezone.com
# 1837            gdelt_investors.com
# 1838            gdelt_investors.com
# 1839             gdelt_liputan6.com
#
#                                                headline  \
# 0                           中国股市逆转早盘涨势收低 之前公布的GDP数据令人失望
# 1      统计局今日公布统计数据 ： 三季度GDP同比增长4 . 9 % 经济由负转正 。 东方财富网博客
# 2     4 Perfect Stocks to Buy if the Stock Market Cr...
# 3      5 Things to Do When the Stock Market Is Volatile
# 4     Wall Street menguat , masih ada ganjalan pada ...
# ...                                                 ...
# 1835  Chart | Wall Street vs Main Street : Why the S...
# 1836  Wall Street Ditutup Menguat Didukung Kenaikan ...
# 1837  Dow Jones Futures : Market Rally , These 5 Sto...
# 1838  Stock Market Drifts Lower After Jobs Data ; 10...
# 1839  Oktober Bikin Khawatir Pelaku Pasar di Wall St...
#
#                                                     url
# 0     https://cn.reuters.com/article/china-stocks-gd...
# 1     http://blog.eastmoney.com/o8326325948088954/bl...
# 2     https://www.fool.com/investing/2020/10/19/4-pe...
# 3     https://www.fool.com/investing/2020/10/21/5-th...
# 4     https://investasi.kontan.co.id/news/wall-stree...
# ...                                                 ...
# 1835  https://www.investmentwatchblog.com/chart-wall...
# 1836  https://economy.okezone.com/read/2021/10/08/27...
# 1837  https://www.investors.com/market-trend/stock-m...
# 1838  https://www.investors.com/market-trend/the-big...
# 1839  https://www.liputan6.com/saham/read/4679780/ok...
#
# [1840 rows x 65 columns]

# %%
pd.DataFrame([prompt]).to_clipboard()

# %%
pipeline._call_gemini(prompt)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 pipeline._call_gemini(prompt)
#
# File c:\\Users\\user\\Desktop\\kz code\\fx-ml-pipeline\src_clean\data_pipelines\silver\news_feature_pipelines.py:327, in NewsLLMFeaturePipeline._call_gemini(self, prompt)
#     322 genai = self._genai
#     323 generation_config = genai.GenerationConfig(
#     324     response_mime_type="application/json",
#     325     response_schema=self.response_schema,
#     326 )
# --> 327 response = self._gemini_model.generate_content(
#     328     prompt,
#     329     generation_config=generation_config,
#     330 )
#     331 content = getattr(response, "text", None)
#     332 if not content:
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\user\anaconda3\envs\fx-ml-pipeline\lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75     return callable_(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# InvalidArgument: 400 * GenerateContentRequest.generation_config.response_schema.properties["entity_sentiment"].properties: should be non-empty for OBJECT type

# %% [markdown]
# ## Tips
#
# - Re-run the parameter cell after updating the date range or maximum articles.
# - If you hit rate limits, increase the gap between runs or manually throttle the helper function.
# - The notebook uses a private helper (`_analyze_article`) for demonstration purposes. For production use, wrap this logic in a dedicated orchestrator that handles persistence and retries as needed.
